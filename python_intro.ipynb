# %% [markdown]
# # 식별자
# •python에서 식별자는 변수, 함수, 모듈, 클래스 등을 식별하는데 사용되는 이름이다.

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
str(5)
# Out:
# '5'

# %%
#str() 이미 있는 식별자의 이름으로 변수를 정하면 함수 호출이 안 됨.ㄴ 
str = "hihi"
str(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-86bd572e418e> in <module>
#       1 str = "hihi"
# ----> 2 str(5)
#
# TypeError: 'str' object is not callable

# %%
#이 뒤에 코드들이 영향이 가기 때문에 str변수를 삭제
del str

# %% [markdown]
# # 기본문법
# ## 인코딩 선언
# 인코딩은 선언하지 않더라도 utf-8로 설정되어있음
# 만약 인코딩 설정을 하려면 아래와 같이 작성ㅎ주셍.

# %%
# -*- coding: encoding -*-

# %% [markdown]
# ##주석(comment)
# - 주석은 #으로 표현
# - docstring은 """으로 표현합니다.=>여러줄 주석

# %%
def mysum(a,b):
    """
    이것은 덧셈함수입니다. 
    이줄은 실행되지 않습니다
    다만 doctstring인 이유가 있습니다.
    """
    print(a+b)

# %%
mysum(1,2)
# Out:
# 3

# %%
mysum.__doc__
# Out:
# '\n    이것은 덧셈함수입니다. \n    이줄은 실행되지 않습니다\n    다만 doctstring인 이유가 있습니다.\n    '

# %% [markdown]
# #코드라인

# %%
print("hello")
print("hi")
# Out:
# hello
# hi

# %%
a = 0
if a == 0:
    print("0")
# Out:
# 0

# %% [markdown]
# - [].{}.[]는 \없이 여러줄로 작성가능

# %% [markdown]
# #변수

# %%
a = 123

# %%
x = 1234
print(x)
print(id(x))
x = 4321
print(x)
print(id(x))
print(type("hihi"))
# Out:
# 1234
# 2322802817232
# 4321
# 2322802817136
# <class 'str'>

# %% [markdown]
# # 변수
#
# - 변수는 = 기호를 사용해서 할당한다.
# - 변수의 메모리 주소를 확인하기 위해서 id()함수를 활용한다.
# - 변수의 자료형을 확인하기 위해서 type()함수를 활용한다.

# %% [markdown]
# - 같은 값을 동시에 할당할 수 있다.

# %% [markdown]
# - 다른 값을 동시에 할당할 수 있다.

# %%
a, b = 1000, 2000
print(a,b)
# Out:
# 1000 2000

# %%
a, b =1000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-e14500a5e83b> in <module>
# ----> 1 a, b =1000
#
# TypeError: 'int' object is not iterable

# %%
a,b =1,2,3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-1f237ab311da> in <module>
# ----> 1 a,b =1,2,3
#
# ValueError: too many values to unpack (expected 2)

# %%
#vpython에서는 쉽게 변수값을 swap할 수 있다!
a = 1
b = 2

a,b = b,a
print(a,b)
# Out:
# 2 1

# %% [markdown]
# # 자료형
# ## 수치형(numbers)
# ## int(정수)
# 모든 정수는 intf로 표현된다.

# %%
a = 3
print(type(a))
# Out:
# <class 'int'>

# %%
a = 2**64
print(type(a))
# Out:
# <class 'int'>

# %%
#파이썬은 오버플로우 노 발생!
import sys
max_int = sys.maxsize
print(max_int)
print(max_int*max_int)
# Out:
# 9223372036854775807
# 85070591730234615847396907784232501249

# %%
binary_num = 0b10
octal_num = 0o10
decimal_num = 10
hexadecimal = 0x10

print(f"""
2진수 : {binary_num}
8진수 : {octal_num}
10진수 : {decimal_num}
16진수 : {hexadecimal}

""")
# Out:
# 2진수 : 2
# 8진수 : 8
# 10진수 : 10
# 16진수 : 16

# %% [markdown]
# ### float(실수, 부동소수점)
# 실수는 float으로 표현된다!
# 실수는 컴퓨터가 표한하는 과정에서 부동소수점을 사용하고, 항상 같은 값으로 일치 안됨
# 이는 컴퓨터가 2진수를 통해 숫자를 표현하는 과정에서 오류가 ㅏㄹ발생함

# %%
a = 3.14
print(type(a))
# Out:
# <class 'float'>

# %%
b = 12e-2
print(b)
# Out:
# 0.12

# %%
# 실수의 경우 실제로 값을 처리할때 주의해야 함

# %%
3.5 - 3.14
# Out:
# 0.3599999999999999

# %%
round(3.5-3.14, 2)
# Out:
# 0.36

# %%
0.1 * 3 == 0.3
# Out:
# False

# %%
# 처리방법 1 - 절대값을 비교
a = 0.1 * 3
b = 0.3

abs(a-b)
# Out:
# 5.551115123125783e-17

# %%
# 처리방법 2 - 절대값 비교를 내장된 함수로 비교

import sys
abs(a-b) <= sys.float_info.epsilon
# Out:
# True

# %%
# 처리방법 3 - math 모듈을 활용해서 비교
import math
math.isclose(a,b)
# Out:
# True

# %% [markdown]
# ## 복소수(complex)

# %%
a = 3 - 4j
print(type(a))
# Out:
# <class 'complex'>

# %%
# 실수부 반환

print(a.real)

#허수부 반환

print(a.imag)

#켤레 복소수 반환

print(a.conjugate())
# Out:
# 3.0
# -4.0
# (3+4j)

# %% [markdown]
# # boolean
# 파이썬에서는 true와 false로 이루어진 Bool타입이 있습니다.(주의!!T와 F는 대문자!!)
# 비교/논리 연산을 위해서 사용됩니다.
# 다음은 False로 변환됩니다.
# - 0, 0.0, (), {}, [], '', None

# %%
print(type(False))
# Out:
# <class 'bool'>

# %% [markdown]
# - 몇가지 데이터를 자동으로 형 변환 시킵니다. 나중에 추가적으로 설명할게요.

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(4564)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool([])
# Out:
# False

# %% [markdown]
# ### None

# %%
type(None)
# Out:
# NoneType

# %%
a = None
print(a)
# Out:
# None

# %% [markdown]
# ## 문자형(String)
# 문자형은 ''(single quotes) ""(double quotes)을 활용해서 표현
# 문자열을 묶을때 하나의 문장부호를 선택!!!

# %%
greeting = "Hi"
name = "Jihee"
print(greeting, name)
# Out:
# Hi Jihee

# %% [markdown]
# - 문자열 안에 문장부호('',"")가 쓰이는 경우 이스케이프 문자를 사용

# %%
print("철수가 말했다 \"안녕?\" "))
# Out:
#   File "<ipython-input-53-c4965a03318c>", line 1
#     print("철수가 말했다 \"안녕?\" "))
#                              ^
# SyntaxError: invalid syntax

# %%
print("철수가 말했다 \"안녕?\"")
# Out:
# 철수가 말했다 "안녕?"

# %% [markdown]
# - 여러줄을 한 번에 표현 가능합니다.

# %%
a = "파이썬 너무 재밌땅"
print(f"""
 개행문자없이 
 그냥 엔터를 치면 한줄 내려감
 {a}
""")
# Out:
#  개행문자없이
#  그냥 엔터를 치면 한줄 내려감
#  파이썬 너무 재밌땅

# %% [markdown]
# - 이스케이프 문자열
# 문자열을 활용할 때 특수 문자를 조작할 떄 사용! \를 활용하여 구분한다.

# %%
print("이 다음은 엔터 \n 안녕하세요")
# Out:
# 이 다음은 엔터
#  안녕하세요

# %%
print("이 다음은 탭 \t 안녕하세요")
# Out:
# 이 다음은 탭 	 안녕하세요

# %%
print("내용을 이어서??", end = '\t')
print("하하")
# Out:
# 내용을 이어서??	하하

# %%
print("개행문자말고도 쓸 수 있나용", end="?")
print("와 신기하다", end = "!")
# Out:
# 개행문자말고도 쓸 수 있나용?와 신기하다!

# %% [markdown]
# "파일은 C:\Windows\Users\내문서에 저장이 되어있습니다."
# 나는 생각했다. 'cd를 써서 git bash로 들어가봐야지'

# %%
print("\"파일은 C:\\Windows\\Users\\내문서에 저장이 되어있습니다.\" \n 나는 생각했다. \'cd를 써서 git bash로 들어가봐야지\'")
# Out:
# "파일은 C:\Windows\Users\내문서에 저장이 되어있습니다."
#  나는 생각했다. 'cd를 써서 git bash로 들어가봐야지'

# %% [markdown]
# ## string interpolation
# 1. %-fomatting
# 2. str.format()
# 3. f-string:3.6이상에서만 지원합니다

# %%
name = "Jihee"

# %%
"hello, %s" % name
# Out:
# 'hello, Jihee'

# %%
"hello, {}".format(name)
# Out:
# 'hello, Jihee'

# %%
f"hello,{name}"
# Out:
# 'hello,Jihee'

# %%
import datetime
today = datetime.datetime.now()
print(today)
# Out:
# 2019-01-02 16:30:45.764164

# %%
f"오늘은 {today:%m}월 {today:%d}일 입니다."
# Out:
# '오늘은 01월 02일 입니다.'

# %%
f"4의 제곱은 {4*4}입니다."
# Out:
# '4의 제곱은 16입니다.'

# %% [markdown]
# # 연산자
# ## 산술 연산자
# - +-*/:사칙연산
# - // : 몫
# - % : 나머지
# - ** : 거듭제곱

# %%
a = 5
print(a)
print(-a)
b = -5
print(+b)
print(-b)
# Out:
# 5
# -5
# -5
# 5

# %% [markdown]
# ## 비교연산자
# - ==:같음
# - !=: 같지 않음

# %%
3>6
# Out:
# False

# %%
3>=2
# Out:
# True

# %%
2=<3
# Out:
#   File "<ipython-input-80-ef3233f9fbcf>", line 1
#     2=<3
#       ^
# SyntaxError: invalid syntax

# %%
2<=3
# Out:
# True

# %% [markdown]
# ### 논리연산자
# - a and b : a,b 모두 true일때 True
# - a or b : a,b모두 false일때 False
# - not a : False ->True, True ->False

# %% [markdown]
# ### 복합연산자
# a = a+1
# a += 1, a-=1
# a//=b
# a %= b

# %% [markdown]
# ## 기타 연산자

# %%
"hi" + "jihee"
# Out:
# 'hijihee'

# %%
"a" in "apple"
# Out:
# True

# %%
a = 1000
b = 1000
a == b
a is b
# Out:
# False

# %% [markdown]
# ### 연산자 우선순위
# 1. ()읕 통한 그룹핑
# 2. Slicing
# 3. Indexing
# 4. 제곱연산자 **
# 5. 단항연산자+-
# 6. 산술연산자 *,/,%
# 7. 산술연산자 +-
# 8. 비교연산자 in is
# 9. not
# 10. and
# 11. or

# %% [markdown]
# ### 형변환
# #### 암시적 형변환
# 파이썬이 그냥 알아서 이거겠지 하고 바꿔주는 형변환
# - bool
# - numbers
#
#
# #### 명시적 형변환

# %%
True + 3
# Out:
# 4

# %%
int_num = 3
float_num = 3.14
complex_num = 3+5j

# %%
print(type(int_num + float_num))
# Out:
# <class 'float'>

# %%
print(type(float_num + complex_num))
# Out:
# <class 'complex'>

# %% [markdown]
# ### 명시적 형변환
# 위에서 적은 암식적 형변환을 제외하고는 명시적으로 형변환을 해줘야 한다.
# - string -> integer : 형식에 맞는 숫자만
# - integer -> string : 모두다 가능

# %%
str(1) + "등"
# Out:
# '1등'

# %%
int("등")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-f97e4185fbb0> in <module>
# ----> 1 int("등")
#
# ValueError: invalid literal for int() with base 10: '등'

# %% [markdown]
# # 시퀀스 자료형
# 시퀀스는 데이터의 순서대로 나열된 형시을 나타낸다.
# 그런데 주의!!!!! 순서대로 나열된 것이 정렬된 건 아니다!
# 파이썬에서 지원하는 시퀀스 타입
# - 리스트
# - 튜플
# - 레인지(range)
# - 문자열(string)
# - 바이너리(binary)

# %% [markdown]
# ### 리스트
# - 활용법
#     - [val1,val2,val3]
#     - 대괄호 활용
#     - 값에 대한 접근은 list[i]를 통해 접근

# %%
l = []
print(type(l))
# Out:
# <class 'list'>

# %% [markdown]
# ## tuple
# - 활용법
#     -(val1, val2)
#     - 리스트와 유사하지만, ()로 묶어서 표현합니다.
#     - 수정불가능합니다. => 읽기만 가능
#     - 실제로 많이 사용하지 않지만 파이썬 내부에서 많이 사용

# %%
t = (1,2)
print(type(t))
# Out:
# <class 'tuple'>

# %%
#파이썬 내부에서는 다음과 같이 사용, a b 바꿀 때도 -> a,b = b,a
a,b =1,2
print(a)
print(b)
# Out:
# 1
# 2

# %% [markdown]
# ### range
# 레인지 숫자의 시퀀스를 나타내기 위해 사용
#     -기본: range(a)
#         - 0~a-1
#      range(a,b)
#         - a~b-1
#      range(a,b,c)
#          -a~b-1까지 c씩 단위로 증가

# %%
print(list(range(1,10,2)))
# Out:
# [1, 3, 5, 7, 9]

# %%
l = [1,2,3]
s = [4,5,6]
print(l+s)
print(l*2)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 1, 2, 3]

# %%
hello = "오늘 하루가 끝나가네요ㅜㅠ"

# %%
hello[5]
# Out:
# '가'

# %%
hello[1:5]
# Out:
# '늘 하루'

# %%
hello[0:10]
# Out:
# '오늘 하루가 끝나가'

# %%
hello[0:10:2]
# Out:
# '오 루 나'

# %% [markdown]
# ## Set, dictionary
# - 이친구 둘다 기본적으로 순서가 없다

# %% [markdown]
# ## set
# - 수학에서 집합과 동일 {}

# %%
set_a = {1,2,3}
set_b = {3,4,5}
print(set_a|set_b)
print(set_a&set_b)
print(set_a-set_b)
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}

# %% [markdown]
# ### dic
# - {key1:value1,key2:value2....}
# - key는 immutable한 모든 것이 가능하다!!!
#  (string, integer,float,boolean,tuple,range)
#  value는 대부분의 값 들어갈 수 있음

# %%
dict_a = {}
dict_b = dict()
#둘다 타입찍으면 dictionary

# %%
phone_book = {"서울":"02", "광주":"062"}
phone_book["광주"]
# Out:
# '062'

# %%
#중복된 Key값을 가질 수 없습니다.
dict_test = {1:5,2:2,1:1}
print(dict_test)
